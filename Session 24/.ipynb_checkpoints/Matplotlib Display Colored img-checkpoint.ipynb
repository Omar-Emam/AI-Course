# %%
import matplotlib.pyplot as plt
import cv2 as cv

# %%
cat = cv.imread('cat.jpg')
plt.xticks([]), plt.yticks([])
plt.imshow(cat)

# %%
cat = cv.imread('cat.jpg')
catRGB = cv.cvtColor(cat, cv.COLOR_BGR2RGB)
plt.xticks([]), plt.yticks([])
plt.imshow(catRGB)
